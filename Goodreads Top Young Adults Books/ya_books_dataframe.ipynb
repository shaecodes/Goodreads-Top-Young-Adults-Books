# %%
import pandas as pd

# %%
df = pd.read_csv('best_ya_books.csv', encoding='latin1')

# %% [markdown]
# A book’s total **score** is based on multiple factors, including the number of people who have voted for it and how highly those voters ranked the book.

# %%
df.head(50)
# Out:
#                                                 Title
# 0   Harry Potter and the Sorcerer's Stone (Harry P...  \
# 1   The Lightning Thief (Percy Jackson and the Oly...
# 2             The Hunger Games (The Hunger Games, #1)
# 3                    Twilight (The Twilight Saga, #1)
# 4                           The Giver (The Giver, #1)
# 5                              The Fault in Our Stars
# 6          City of Bones (The Mortal Instruments, #1)
# 7                           Divergent (Divergent, #1)
# 8                                      The Book Thief
# 9                               To Kill a Mockingbird
# 10                    The Perks of Being a Wallflower
# 11             The Hobbit (The Lord of the Rings, #0)
# 12                                  Holes (Holes, #1)
# 13                                      The Outsiders
# 14        The Golden Compass (His Dark Materials, #1)
# 15                            The Host (The Host, #1)
# ...
